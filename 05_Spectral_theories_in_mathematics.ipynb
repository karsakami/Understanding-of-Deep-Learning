# %% [markdown]
# <a href="https://colab.research.google.com/github/karsakami/Understanding-of-Deep-Learning/blob/main/05_Spectral_theories_in_mathematics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###In spectral theories we need to just break complicated things into simple things. Like a rainbow, we just sum these colors to make it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###For example - there is *fourier transform* used in signal processing and image processing. The idea behind it is to brake it to simple things. The whole, complex signal consists of several simple signals.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Good examples of this is *linear algebra* , where we can represent matrix $A$ in a different form.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###What does this have to do with Deep Learning?
#
# ###We can just break the math behind DL into collection of simple streight forward operations.
#
# **DL** is:
# * **Simple**, because its made of simple, basic math (mostly - we talk about computations between layers)
# * **Complicated** because contains many parts (many layers)
# * **Complex** cuz of myriad nonlinearities (*activation functions*) and because it is unituive
#
# \
#
# ###Lets understand now a difference between **complicated** and **complex** things.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
