# %% [markdown]
# <a href="https://colab.research.google.com/github/karsakami/Understanding-of-Deep-Learning/blob/main/04_Comparing_the_actual_neurons_to_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **We will discuss about**
#
#
# *   Real neurones
# *   ANN, which are nothing like real neurones

# %% [markdown]
# ---
# ## **Real neurones**
# Basically, there are huge diversity of neurones, and no neuron is the same. \
#
# \
# ###*Left image*
# Orange ball in the center is called **SOMA** (the cell body), arms are dendrites. Neuron makes physical contact with other neurones via **synapses**, which are these dots at the entire synapse.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There is entire field in neuroscience called ***Computional neuroscience***. \
# The goal of this field is to understand as much as possible about neurones. The principles of how they work, interact, how they are built, all of these with the help of computers. These are real *ANN*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So lets see at actual neural - the processes in these are waaay more complex than *ANN*, which are just repetition of basic arithmetics.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As we can see, this look way more poor than real neurons, compare davinci's paintings to those of a 4 year old.
#
# But its just terminology, doesn't have much in common with real neurones, but its technology. We dont say that airplanes are not like real birds, or cars are not like real horses!

# %% [markdown]
# ![image.png](data:image/png;base64,...)
