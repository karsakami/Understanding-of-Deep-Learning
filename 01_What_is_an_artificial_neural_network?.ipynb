# %% [markdown]
# <a href="https://colab.research.google.com/github/karsakami/Understanding-of-Deep-Learning/blob/main/01_What_is_an_artificial_neural_network%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## What is an artificial neural network?
# Neural network is some algorithm that analyze some input (for example our web browser history) and we get some output, which can be many things, for example a recommendation of ads that you will more likely to click.
#
# Antother example is algorithm that take your personal medical info and predict, that you can have some disease \
# Self driving cars have cameras and given image pixel values in the image, a deep learning model need to determine if there is a pedestrian about to walk in front of the car

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# All the math inside this mystery box is really simple and its mainly basic arithmetic

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## EXAMPLES

# %% [markdown]
# Another example: Our algorithm try to predict whether a student pass an exam, based on how many hours did he sleept. We generated a fake data for this. A blue dot represent student who passed, and red who not. \
# We easly can see - the more a student studied and slept, the more likely he or she was to pass.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lets just draw a line which separate a different values. So, based on the line, we predict that every value on the left will be negative, and every on the right will be positive. It isnt perfect, but its good.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  In machine learning we can solve it with logistic regression, but we will use neural networks. \
#  So we have our inputs $X_1$ and $X_2$, which is hours studied and hours sleep, a $X_0$ is called bias, then we compute weigh sum and deliver it to activation function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Another example. As we can see, now we cant separate our data with line, so we need non linear solution.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If we think for a while we can deduce that we can solve it by drawing a circle, but in deep learning we dont need to do it because a model will figure it out by itself.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Math of DL
# As we said, a big part of DL is really simple. \
# We say that $y$ is a value that we try to predict, for example the exam score, the $x_1$ on blue is data, features like how many hours student sleep, or how many hours they study. And then, on yellow, is weight, this weight tells the importance of a feature. These weights are learned by model, with help of backpropagation, we dont specify them. For example, if one of our features is the number of lemons eaten in a model that is supposed to predict test scores, the model will by itself conclude, that its not importan and have no impact on exam score, so it wil set the weight = 0
#
# But this equation is linear. How we know that? Because it consist of multiplication and sum.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Since we cant solve a non linear problem with linear equation, we pass the equation to non linear function, this red, called sigma. \
# This function is something simple, and the simpler they are, the better they work.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This is just this one calculation, repeated many times

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Deep learning architectures.
# We use different deep learning architectures to solve different problems, but they are really similar, and the math behind it is the same. We can see analogies in the buildings - office buildings, houses, malls look very different on the outside, but their inner-workings are the same.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
